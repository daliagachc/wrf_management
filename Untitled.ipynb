# %%
path = './du.log'

# %%
import pandas as pd
df = pd.read_csv(path,
                names=['mem','path'],
                 sep='\t'
                )
import numpy as np

df['mem']=np.round(df['mem']/1000000)
df.sort_values('mem',ascending=False)
# Out:
#          mem                                               path
# 4509  5880.0                                                 ./
# 2243  4902.0                              ./wrf_management_data
# 2239  3858.0                         ./wrf_management_data/runs
# 2238  2383.0          ./wrf_management_data/runs/run_2019_02_20
# 168    925.0                                     ./saltena_2018
# 207    801.0        ./wrf_management_data/runs/run_2019_02_28_1
# 206    800.0    ./wrf_management_data/runs/run_2019_02_28_1/wrf
# 2240   669.0                    ./wrf_management_data/press_tar
# 216    443.0          ./wrf_management_data/runs/run_2019_03_01
# 215    442.0      ./wrf_management_data/runs/run_2019_03_01/wrf
# 2241   371.0                   ./wrf_management_data/surf_1_tar
# 167    316.0                 ./saltena_2018/tucu-april-data-v07
# 165    313.0             ./saltena_2018/tucu-april-data-v07/WRF
# 22     221.0                 ./saltena_2018/tucu-april-data-v08
# ...
