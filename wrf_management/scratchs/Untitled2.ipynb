# %%
import subprocess

# %%
pr = subprocess.run(["ls", "-l", "/dev/null"], stdout=subprocess.PIPE)

# %%
pr = subprocess.run(["sleep", "5"], stdout=subprocess.PIPE)

# %%
from subprocess import Popen, PIPE
process = Popen(['sleep', '20',';','echo','"hola"'], stdout=PIPE, stderr=PIPE)

# %%
import wrf_management.project_global_constants as gc
import wrf_management.utilities as ut
import wrf_management.run_utilities as ru
import importlib
rl = [gc,ut,ru]
for m in rl: importlib.reload(m)

# %%
rdp = ut.get_run_data_path()

# %%
import glob
import pandas as pd
paths = glob.glob(rdp+'/20*')
df = pd.DataFrame(paths,columns=['paths'])
df
# Out:
#                                                  paths
# 0    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 1    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 2    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 3    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 4    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 5    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 6    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 7    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 8    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 9    /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 10   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 11   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 12   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 13   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 14   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 15   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 16   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 17   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 18   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 19   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 20   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 21   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 22   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 23   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 24   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 25   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 26   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 27   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 28   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 29   /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# ..                                                 ...
# 118  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 119  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 120  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 121  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 122  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 123  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 124  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 125  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 126  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 127  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 128  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 129  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 130  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 131  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 132  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 133  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 134  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 135  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 136  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 137  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 138  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 139  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 140  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 141  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 142  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 143  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 144  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 145  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 146  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
# 147  /wrk/aliagadi/DONOTREMOVE/wrf_management_data/...
#
# [148 rows x 1 columns]

# %%
stdout, stderr
# Out:
# (b'',
#  b'sleep: invalid time interval `;\'\nsleep: invalid time interval `echo\'\nsleep: invalid time interval `"hola"\'\nTry `sleep --help\' for more information.\n')

# %%
process.communicate('echo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-cc34e2476024> in <module>
# ----> 1 process.communicate('echo')
#
# ~/appl_taito/miniconda3/envs/b36/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     836
#     837         if self._communication_started and input:
# --> 838             raise ValueError("Cannot send input after starting communication")
#     839
#     840         # Optimization: If we are not worried about timeouts, we haven't
#
# ValueError: Cannot send input after starting communication
