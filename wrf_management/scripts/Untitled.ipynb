# %%
ii = 50
for i in range(50):
    # %run './metgrid.py'
    print (i)
# Out:
# run_2019_02_20
# index                             1
# run_name             run_2019_02_20
# geogrid_path                geogrid
# config_path          run_2019_02_20
# data_path       runs/run_2019_02_20
# Name: 0, dtype: object
# /wrk/aliagadi/DONOTREMOVE/wrf_management_data/runs/run_2019_02_20
# date              2017-12-03 00:00:00
# ungrib_surf                       100
# ungrib_press                      100
# ungrib_lake                         0
# ungrib_avgtsfc                    100
# metgrid                             0
# Name: 0, dtype: object
# /wrk/aliagadi/DONOTREMOVE/wrf_management_data/runs/run_2019_02_20/2017_12_03/metgrid
# /homeappl/home/aliagadi/saltena_2018/wrf_management/wrf_management/config_dir/run_2019_02_20
# env_WRFv4.bash
# metgrid.exe
# metgrid
# #!/bin/bash
#     cd /wrk/aliagadi/DONOTREMOVE/wrf_management_data/runs/run_2019_02_20/2017_12_03/metgrid
#     source ./env_WRFv4.bash
#     ./metgrid.exe
#     exit $?
#
# 0
# run_2019_02_20
# ...
