# %%
import wrf_management.base_namelists.base_namelists as nl
import importlib
importlib.reload(nl);

# %%
res,df,df_full = nl.sanity_check(path_wps='./namelist.wps',path_wrf='./namelist.input')
print(res)
df
# Out:
# True
#                                                         d1  \
# dx                 [38000.0, 9500.0, 3166.6667, 1055.5556]
# dy                 [38000.0, 9500.0, 3166.6667, 1055.5556]
# e_sn                                   [86, 205, 214, 151]
# e_we                                  [118, 253, 274, 154]
# i_parent_start                             [1, 28, 80, 61]
# interval_seconds                                     21600
# j_parent_start                            [1, 18, 65, 110]
# max_dom                                                  4
# parent_grid_ratio                             [1, 4, 3, 3]
# parent_id                                     [1, 1, 2, 3]
#
#                                      d2  pass
# dx                                38000  True
# dy                                38000  True
# e_sn                [86, 205, 214, 151]  True
# e_we               [118, 253, 274, 154]  True
# i_parent_start          [1, 28, 80, 61]  True
# interval_seconds                  21600  True
# j_parent_start         [1, 18, 65, 110]  True
# max_dom                               4  True
# parent_grid_ratio          [1, 4, 3, 3]  True
# parent_id                  [1, 1, 2, 3]  True

# %%
df_full
# Out:
#                                   time_control  \
# base_temp                                  NaN
# bl_pbl_physics                             NaN
# bldt                                       NaN
# cam_abs_dim1                               NaN
# cam_abs_dim2                               NaN
# cam_abs_freq_s                             NaN
# cu_physics                                 NaN
# cudt                                       NaN
# damp_opt                                   NaN
# dampcoef                                   NaN
# debug_level                                  0
# diff_6th_factor                            NaN
# diff_6th_opt                               NaN
# diff_opt                                   NaN
# dx                                         NaN
# dy                                         NaN
# e_sn                                       NaN
# e_vert                                     NaN
# e_we                                       NaN
# end_date                                   NaN
# end_day                           [8, 8, 8, 8]
# end_hour                          [6, 6, 6, 6]
# end_month                         [4, 4, 4, 4]
# end_year              [2018, 2018, 2018, 2018]
# ensdim                                     NaN
# feedback                                   NaN
# fg_name                                    NaN
# frames_per_outfile                [6, 6, 6, 6]
# geog_data_path                             NaN
# geog_data_res                              NaN
# ...                                        ...
# run_hours                                    0
# run_minutes                                  0
# run_seconds                                  0
# scalar_adv_opt                             NaN
# seaice_threshold                           NaN
# sf_sfclay_physics                          NaN
# sf_surface_physics                         NaN
# sf_urban_physics                           NaN
# slope_rad                                  NaN
# smooth_option                              NaN
# spec_bdy_width                             NaN
# spec_zone                                  NaN
# specified                                  NaN
# sst_update                                 NaN
# stand_lon                                  NaN
# start_date                                 NaN
# start_day                         [5, 5, 5, 5]
# start_hour                        [6, 6, 6, 6]
# start_month                       [4, 4, 4, 4]
# start_year            [2018, 2018, 2018, 2018]
# surface_input_source                       NaN
# time_step                                  NaN
# time_step_fract_den                        NaN
# time_step_fract_num                        NaN
# topo_shading                               NaN
# truelat1                                   NaN
# truelat2                                   NaN
# w_damping                                  NaN
# wrf_core                                   NaN
# zdamp                                      NaN
#
#                                                       domains       physics  \
# base_temp                                                 NaN           NaN
# bl_pbl_physics                                            NaN  [2, 2, 2, 2]
# bldt                                                      NaN  [0, 0, 0, 0]
# cam_abs_dim1                                              NaN             4
# cam_abs_dim2                                              NaN            45
# cam_abs_freq_s                                            NaN         21600
# cu_physics                                                NaN  [3, 3, 0, 0]
# cudt                                                      NaN  [5, 5, 5, 5]
# damp_opt                                                  NaN           NaN
# dampcoef                                                  NaN           NaN
# debug_level                                               NaN           NaN
# diff_6th_factor                                           NaN           NaN
# diff_6th_opt                                              NaN           NaN
# diff_opt                                                  NaN           NaN
# dx                    [38000.0, 9500.0, 3166.6667, 1055.5556]           NaN
# dy                    [38000.0, 9500.0, 3166.6667, 1055.5556]           NaN
# e_sn                                      [86, 205, 214, 151]           NaN
# e_vert                                       [50, 50, 50, 50]           NaN
# e_we                                     [118, 253, 274, 154]           NaN
# end_date                                                  NaN           NaN
# end_day                                                   NaN           NaN
# end_hour                                                  NaN           NaN
# end_month                                                 NaN           NaN
# end_year                                                  NaN           NaN
# ensdim                                                    NaN           144
# feedback                                                    0           NaN
# fg_name                                                   NaN           NaN
# frames_per_outfile                                        NaN           NaN
# geog_data_path                                            NaN           NaN
# geog_data_res                                             NaN           NaN
# ...                                                       ...           ...
# run_hours                                                 NaN           NaN
# run_minutes                                               NaN           NaN
# run_seconds                                               NaN           NaN
# scalar_adv_opt                                            NaN           NaN
# seaice_threshold                                          NaN           263
# sf_sfclay_physics                                         NaN  [2, 2, 2, 2]
# sf_surface_physics                                        NaN  [2, 2, 2, 2]
# sf_urban_physics                                          NaN  [0, 0, 0, 0]
# slope_rad                                                 NaN  [0, 0, 1, 1]
# smooth_option                                               0           NaN
# spec_bdy_width                                            NaN           NaN
# spec_zone                                                 NaN           NaN
# specified                                                 NaN           NaN
# sst_update                                                NaN             0
# stand_lon                                                 NaN           NaN
# start_date                                                NaN           NaN
# start_day                                                 NaN           NaN
# start_hour                                                NaN           NaN
# start_month                                               NaN           NaN
# start_year                                                NaN           NaN
# surface_input_source                                      NaN             1
# time_step                                                  90           NaN
# time_step_fract_den                                         1           NaN
# time_step_fract_num                                         0           NaN
# topo_shading                                              NaN  [0, 0, 1, 1]
# truelat1                                                  NaN           NaN
# truelat2                                                  NaN           NaN
# w_damping                                                 NaN           NaN
# wrf_core                                                  NaN           NaN
# zdamp                                                     NaN           NaN
#
#                       fdda                          dynamics  \
# base_temp              NaN                               290
# bl_pbl_physics         NaN                               NaN
# bldt                   NaN                               NaN
# cam_abs_dim1           NaN                               NaN
# cam_abs_dim2           NaN                               NaN
# cam_abs_freq_s         NaN                               NaN
# cu_physics             NaN                               NaN
# cudt                   NaN                               NaN
# damp_opt               NaN                                 3
# dampcoef               NaN              [0.2, 0.2, 0.2, 0.2]
# debug_level            NaN                               NaN
# diff_6th_factor        NaN          [0.12, 0.12, 0.12, 0.12]
# diff_6th_opt           NaN                      [0, 0, 0, 0]
# diff_opt               NaN                                 1
# dx                     NaN                               NaN
# dy                     NaN                               NaN
# e_sn                   NaN                               NaN
# e_vert                 NaN                               NaN
# e_we                   NaN                               NaN
# end_date               NaN                               NaN
# end_day                NaN                               NaN
# end_hour               NaN                               NaN
# end_month              NaN                               NaN
# end_year               NaN                               NaN
# ensdim                 NaN                               NaN
# feedback               NaN                               NaN
# fg_name                NaN                               NaN
# frames_per_outfile     NaN                               NaN
# geog_data_path         NaN                               NaN
# geog_data_res          NaN                               NaN
# ...                    ...                               ...
# run_hours              NaN                               NaN
# run_minutes            NaN                               NaN
# run_seconds            NaN                               NaN
# scalar_adv_opt         NaN                      [1, 1, 1, 1]
# seaice_threshold       NaN                               NaN
# sf_sfclay_physics      NaN                               NaN
# sf_surface_physics     NaN                               NaN
# sf_urban_physics       NaN                               NaN
# slope_rad              NaN                               NaN
# smooth_option          NaN                               NaN
# spec_bdy_width         NaN                               NaN
# spec_zone              NaN                               NaN
# specified              NaN                               NaN
# sst_update             NaN                               NaN
# stand_lon              NaN                               NaN
# start_date             NaN                               NaN
# start_day              NaN                               NaN
# start_hour             NaN                               NaN
# start_month            NaN                               NaN
# start_year             NaN                               NaN
# surface_input_source   NaN                               NaN
# time_step              NaN                               NaN
# time_step_fract_den    NaN                               NaN
# time_step_fract_num    NaN                               NaN
# topo_shading           NaN                               NaN
# truelat1               NaN                               NaN
# truelat2               NaN                               NaN
# w_damping              NaN                                 1
# wrf_core               NaN                               NaN
# zdamp                  NaN  [5000.0, 5000.0, 5000.0, 5000.0]
#
#                                       bdy_control  grib2  namelist_quilt  \
# base_temp                                     NaN    NaN             NaN
# bl_pbl_physics                                NaN    NaN             NaN
# bldt                                          NaN    NaN             NaN
# cam_abs_dim1                                  NaN    NaN             NaN
# cam_abs_dim2                                  NaN    NaN             NaN
# cam_abs_freq_s                                NaN    NaN             NaN
# cu_physics                                    NaN    NaN             NaN
# cudt                                          NaN    NaN             NaN
# damp_opt                                      NaN    NaN             NaN
# dampcoef                                      NaN    NaN             NaN
# debug_level                                   NaN    NaN             NaN
# diff_6th_factor                               NaN    NaN             NaN
# diff_6th_opt                                  NaN    NaN             NaN
# diff_opt                                      NaN    NaN             NaN
# dx                                            NaN    NaN             NaN
# dy                                            NaN    NaN             NaN
# e_sn                                          NaN    NaN             NaN
# e_vert                                        NaN    NaN             NaN
# e_we                                          NaN    NaN             NaN
# end_date                                      NaN    NaN             NaN
# end_day                                       NaN    NaN             NaN
# end_hour                                      NaN    NaN             NaN
# end_month                                     NaN    NaN             NaN
# end_year                                      NaN    NaN             NaN
# ensdim                                        NaN    NaN             NaN
# feedback                                      NaN    NaN             NaN
# fg_name                                       NaN    NaN             NaN
# frames_per_outfile                            NaN    NaN             NaN
# geog_data_path                                NaN    NaN             NaN
# geog_data_res                                 NaN    NaN             NaN
# ...                                           ...    ...             ...
# run_hours                                     NaN    NaN             NaN
# run_minutes                                   NaN    NaN             NaN
# run_seconds                                   NaN    NaN             NaN
# scalar_adv_opt                                NaN    NaN             NaN
# seaice_threshold                              NaN    NaN             NaN
# sf_sfclay_physics                             NaN    NaN             NaN
# sf_surface_physics                            NaN    NaN             NaN
# sf_urban_physics                              NaN    NaN             NaN
# slope_rad                                     NaN    NaN             NaN
# smooth_option                                 NaN    NaN             NaN
# spec_bdy_width                                  5    NaN             NaN
# spec_zone                                       1    NaN             NaN
# specified             [True, False, False, False]    NaN             NaN
# sst_update                                    NaN    NaN             NaN
# stand_lon                                     NaN    NaN             NaN
# start_date                                    NaN    NaN             NaN
# start_day                                     NaN    NaN             NaN
# start_hour                                    NaN    NaN             NaN
# start_month                                   NaN    NaN             NaN
# start_year                                    NaN    NaN             NaN
# surface_input_source                          NaN    NaN             NaN
# time_step                                     NaN    NaN             NaN
# time_step_fract_den                           NaN    NaN             NaN
# time_step_fract_num                           NaN    NaN             NaN
# topo_shading                                  NaN    NaN             NaN
# truelat1                                      NaN    NaN             NaN
# truelat2                                      NaN    NaN             NaN
# w_damping                                     NaN    NaN             NaN
# wrf_core                                      NaN    NaN             NaN
# zdamp                                         NaN    NaN             NaN
#
#                                                                   share  \
# base_temp                                                           NaN
# bl_pbl_physics                                                      NaN
# bldt                                                                NaN
# cam_abs_dim1                                                        NaN
# cam_abs_dim2                                                        NaN
# cam_abs_freq_s                                                      NaN
# cu_physics                                                          NaN
# cudt                                                                NaN
# damp_opt                                                            NaN
# dampcoef                                                            NaN
# debug_level                                                         NaN
# diff_6th_factor                                                     NaN
# diff_6th_opt                                                        NaN
# diff_opt                                                            NaN
# dx                                                                  NaN
# dy                                                                  NaN
# e_sn                                                                NaN
# e_vert                                                              NaN
# e_we                                                                NaN
# end_date              [2018-04-08_06:00:00, 2018-04-08_06:00:00, 201...
# end_day                                                             NaN
# end_hour                                                            NaN
# end_month                                                           NaN
# end_year                                                            NaN
# ensdim                                                              NaN
# feedback                                                            NaN
# fg_name                                                             NaN
# frames_per_outfile                                                  NaN
# geog_data_path                                                      NaN
# geog_data_res                                                       NaN
# ...                                                                 ...
# run_hours                                                           NaN
# run_minutes                                                         NaN
# run_seconds                                                         NaN
# scalar_adv_opt                                                      NaN
# seaice_threshold                                                    NaN
# sf_sfclay_physics                                                   NaN
# sf_surface_physics                                                  NaN
# sf_urban_physics                                                    NaN
# slope_rad                                                           NaN
# smooth_option                                                       NaN
# spec_bdy_width                                                      NaN
# spec_zone                                                           NaN
# specified                                                           NaN
# sst_update                                                          NaN
# stand_lon                                                           NaN
# start_date            [2018-04-05_06:00:00, 2018-04-05_06:00:00, 201...
# start_day                                                           NaN
# start_hour                                                          NaN
# start_month                                                         NaN
# start_year                                                          NaN
# surface_input_source                                                NaN
# time_step                                                           NaN
# time_step_fract_den                                                 NaN
# time_step_fract_num                                                 NaN
# topo_shading                                                        NaN
# truelat1                                                            NaN
# truelat2                                                            NaN
# w_damping                                                           NaN
# wrf_core                                                            ARW
# zdamp                                                               NaN
#
#                                                    geogrid ungrib  \
# base_temp                                              NaN    NaN
# bl_pbl_physics                                         NaN    NaN
# bldt                                                   NaN    NaN
# cam_abs_dim1                                           NaN    NaN
# cam_abs_dim2                                           NaN    NaN
# cam_abs_freq_s                                         NaN    NaN
# cu_physics                                             NaN    NaN
# cudt                                                   NaN    NaN
# damp_opt                                               NaN    NaN
# dampcoef                                               NaN    NaN
# debug_level                                            NaN    NaN
# diff_6th_factor                                        NaN    NaN
# diff_6th_opt                                           NaN    NaN
# diff_opt                                               NaN    NaN
# dx                                                   38000    NaN
# dy                                                   38000    NaN
# e_sn                                   [86, 205, 214, 151]    NaN
# e_vert                                                 NaN    NaN
# e_we                                  [118, 253, 274, 154]    NaN
# end_date                                               NaN    NaN
# end_day                                                NaN    NaN
# end_hour                                               NaN    NaN
# end_month                                              NaN    NaN
# end_year                                               NaN    NaN
# ensdim                                                 NaN    NaN
# feedback                                               NaN    NaN
# fg_name                                                NaN    NaN
# frames_per_outfile                                     NaN    NaN
# geog_data_path                     /proj/atm/WRF/WPS_GEOG/    NaN
# geog_data_res         [default, default, default, default]    NaN
# ...                                                    ...    ...
# run_hours                                              NaN    NaN
# run_minutes                                            NaN    NaN
# run_seconds                                            NaN    NaN
# scalar_adv_opt                                         NaN    NaN
# seaice_threshold                                       NaN    NaN
# sf_sfclay_physics                                      NaN    NaN
# sf_surface_physics                                     NaN    NaN
# sf_urban_physics                                       NaN    NaN
# slope_rad                                              NaN    NaN
# smooth_option                                          NaN    NaN
# spec_bdy_width                                         NaN    NaN
# spec_zone                                              NaN    NaN
# specified                                              NaN    NaN
# sst_update                                             NaN    NaN
# stand_lon                                            -66.3    NaN
# start_date                                             NaN    NaN
# start_day                                              NaN    NaN
# start_hour                                             NaN    NaN
# start_month                                            NaN    NaN
# start_year                                             NaN    NaN
# surface_input_source                                   NaN    NaN
# time_step                                              NaN    NaN
# time_step_fract_den                                    NaN    NaN
# time_step_fract_num                                    NaN    NaN
# topo_shading                                           NaN    NaN
# truelat1                                                30    NaN
# truelat2                                                60    NaN
# w_damping                                              NaN    NaN
# wrf_core                                               NaN    NaN
# zdamp                                                  NaN    NaN
#
#                                   metgrid
# base_temp                             NaN
# bl_pbl_physics                        NaN
# bldt                                  NaN
# cam_abs_dim1                          NaN
# cam_abs_dim2                          NaN
# cam_abs_freq_s                        NaN
# cu_physics                            NaN
# cudt                                  NaN
# damp_opt                              NaN
# dampcoef                              NaN
# debug_level                           NaN
# diff_6th_factor                       NaN
# diff_6th_opt                          NaN
# diff_opt                              NaN
# dx                                    NaN
# dy                                    NaN
# e_sn                                  NaN
# e_vert                                NaN
# e_we                                  NaN
# end_date                              NaN
# end_day                               NaN
# end_hour                              NaN
# end_month                             NaN
# end_year                              NaN
# ensdim                                NaN
# feedback                              NaN
# fg_name               [SURFACE, PRESSURE]
# frames_per_outfile                    NaN
# geog_data_path                        NaN
# geog_data_res                         NaN
# ...                                   ...
# run_hours                             NaN
# run_minutes                           NaN
# run_seconds                           NaN
# scalar_adv_opt                        NaN
# seaice_threshold                      NaN
# sf_sfclay_physics                     NaN
# sf_surface_physics                    NaN
# sf_urban_physics                      NaN
# slope_rad                             NaN
# smooth_option                         NaN
# spec_bdy_width                        NaN
# spec_zone                             NaN
# specified                             NaN
# sst_update                            NaN
# stand_lon                             NaN
# start_date                            NaN
# start_day                             NaN
# start_hour                            NaN
# start_month                           NaN
# start_year                            NaN
# surface_input_source                  NaN
# time_step                             NaN
# time_step_fract_den                   NaN
# time_step_fract_num                   NaN
# topo_shading                          NaN
# truelat1                              NaN
# truelat2                              NaN
# w_damping                             NaN
# wrf_core                              NaN
# zdamp                                 NaN
#
# [116 rows x 12 columns]
